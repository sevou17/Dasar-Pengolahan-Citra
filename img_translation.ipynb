# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# load gambar
img = cv2.imread('kadal.jpg')

# Matriks translasi
x = 100  # translasi horizontal
y = 50  # translasi vertikal
M = np.float32([[1, 0, x], [0, 1, y]])

# translasi gambar
translated_img = cv2.warpAffine(img, M, (img.shape[1], img.shape[0]))

# menampilkan gambar asli dan hasil translasi
plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis()

plt.subplot(1, 2, 2)
plt.title('Translated Image')
plt.imshow(cv2.cvtColor(translated_img, cv2.COLOR_BGR2RGB))
plt.axis()

plt.show()
